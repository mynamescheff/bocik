# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# Define the input and output directories
input_dir = 'img/not_labeled_stones/'
output_dir = 'img/not_labeled_stones/boxes/'

# Iterate through all full image files in the input directory
for filename in os.listdir(input_dir):
    if filename.startswith('Screenshot_') and filename.endswith('.png'):
        full_img_path = os.path.join(input_dir, filename)
        full_img = cv.imread(full_img_path, cv.IMREAD_GRAYSCALE)
        
        # Extract the image number from the filename
        img_number = filename.split('_')[1].split('.')[0]
        
        # Find corresponding stone image based on the extracted image number
        stone_img_filename = f'cropped_Screenshot_{img_number}.png'
        stone_img_path = os.path.join(input_dir, 'cropped', stone_img_filename)
        stone_img = cv.imread(stone_img_path, cv.IMREAD_GRAYSCALE)

        result = cv.matchTemplate(full_img, stone_img, cv.TM_CCOEFF_NORMED)

        min_val, max_val, min_loc, max_loc = cv.minMaxLoc(result)

        threshold = 0.6
        if max_val >= threshold:
            print("Object found in %s with confidence: %.2f" % (filename, max_val))

            w = stone_img.shape[1]
            h = stone_img.shape[0]
            top_left = max_loc
            bottom_right = (top_left[0] + w, top_left[1] + h)

            cv.rectangle(full_img, top_left, bottom_right, (0, 0, 255), 2)

            # Save the image with the box
            output_img_filename = f'{filename.split(".")[0]}_box.png'
            output_img_path = os.path.join(output_dir, output_img_filename)
            cv.imwrite(output_img_path, full_img)
        else:
            print("Object not found in %s. Confidence: %.2f" % (filename, max_val))

print("Detection and saving complete.")
# Out:
# Object found in Screenshot_1.png with confidence: 1.00
# Object found in Screenshot_10.png with confidence: 0.99
# Object found in Screenshot_100.png with confidence: 0.87
# Object found in Screenshot_101.png with confidence: 0.84
# Object found in Screenshot_102.png with confidence: 0.70
# Object found in Screenshot_103.png with confidence: 0.73
# Object not found in Screenshot_104.png. Confidence: 0.51
# Object not found in Screenshot_105.png. Confidence: 0.42
# Object found in Screenshot_106.png with confidence: 0.99
# Object found in Screenshot_107.png with confidence: 1.00
# Object found in Screenshot_108.png with confidence: 1.00
# Object found in Screenshot_109.png with confidence: 1.00
# Object found in Screenshot_11.png with confidence: 0.99
# Object found in Screenshot_110.png with confidence: 1.00
# Object found in Screenshot_12.png with confidence: 0.99
# Object found in Screenshot_13.png with confidence: 0.99
# Object found in Screenshot_14.png with confidence: 0.99
# Object found in Screenshot_15.png with confidence: 1.00
# Object found in Screenshot_16.png with confidence: 1.00
# Object found in Screenshot_17.png with confidence: 0.99
# Object found in Screenshot_18.png with confidence: 1.00
# Object found in Screenshot_19.png with confidence: 1.00
# Object found in Screenshot_2.png with confidence: 1.00
# Object found in Screenshot_20.png with confidence: 1.00
# Object found in Screenshot_21.png with confidence: 1.00
# Object found in Screenshot_22.png with confidence: 1.00
# Object found in Screenshot_23.png with confidence: 1.00
# Object found in Screenshot_24.png with confidence: 1.00
# Object found in Screenshot_25.png with confidence: 1.00
# Object found in Screenshot_26.png with confidence: 1.00
# Object found in Screenshot_27.png with confidence: 1.00
# Object found in Screenshot_28.png with confidence: 1.00
# Object found in Screenshot_29.png with confidence: 1.00
# Object found in Screenshot_3.png with confidence: 1.00
# Object found in Screenshot_30.png with confidence: 1.00
# Object found in Screenshot_31.png with confidence: 1.00
# Object found in Screenshot_32.png with confidence: 1.00
# Object found in Screenshot_33.png with confidence: 1.00
# Object found in Screenshot_34.png with confidence: 1.00
# Object found in Screenshot_35.png with confidence: 1.00
# Object found in Screenshot_36.png with confidence: 1.00
# Object found in Screenshot_37.png with confidence: 1.00
# Object found in Screenshot_38.png with confidence: 1.00
# Object found in Screenshot_39.png with confidence: 1.00
# Object found in Screenshot_4.png with confidence: 1.00
# Object found in Screenshot_40.png with confidence: 1.00
# Object found in Screenshot_41.png with confidence: 1.00
# Object found in Screenshot_42.png with confidence: 1.00
# Object found in Screenshot_43.png with confidence: 1.00
# Object found in Screenshot_44.png with confidence: 1.00
# Object found in Screenshot_45.png with confidence: 1.00
# Object found in Screenshot_46.png with confidence: 1.00
# Object found in Screenshot_47.png with confidence: 0.95
# Object found in Screenshot_48.png with confidence: 0.99
# Object found in Screenshot_49.png with confidence: 1.00
# Object found in Screenshot_5.png with confidence: 0.98
# Object found in Screenshot_50.png with confidence: 1.00
# Object found in Screenshot_51.png with confidence: 1.00
# Object found in Screenshot_52.png with confidence: 0.97
# Object found in Screenshot_53.png with confidence: 1.00
# Object found in Screenshot_54.png with confidence: 0.99
# Object found in Screenshot_55.png with confidence: 1.00
# Object found in Screenshot_56.png with confidence: 0.99
# Object found in Screenshot_57.png with confidence: 1.00
# Object found in Screenshot_58.png with confidence: 1.00
# Object found in Screenshot_59.png with confidence: 1.00
# Object found in Screenshot_6.png with confidence: 0.99
# Object found in Screenshot_60.png with confidence: 1.00
# Object found in Screenshot_61.png with confidence: 1.00
# Object found in Screenshot_62.png with confidence: 1.00
# Object found in Screenshot_63.png with confidence: 1.00
# Object found in Screenshot_64.png with confidence: 1.00
# Object found in Screenshot_65.png with confidence: 1.00
# Object found in Screenshot_66.png with confidence: 1.00
# Object not found in Screenshot_67.png. Confidence: 0.57
# Object not found in Screenshot_68.png. Confidence: 0.51
# Object not found in Screenshot_69.png. Confidence: 0.50
# Object found in Screenshot_7.png with confidence: 0.99
# Object not found in Screenshot_70.png. Confidence: 0.51
# Object not found in Screenshot_71.png. Confidence: 0.23
# Object not found in Screenshot_72.png. Confidence: 0.54
# Object found in Screenshot_73.png with confidence: 0.70
# Object found in Screenshot_74.png with confidence: 0.73
# Object found in Screenshot_75.png with confidence: 0.70
# Object not found in Screenshot_76.png. Confidence: 0.44
# Object found in Screenshot_77.png with confidence: 0.91
# Object not found in Screenshot_78.png. Confidence: 0.43
# Object found in Screenshot_79.png with confidence: 0.79
# Object found in Screenshot_8.png with confidence: 0.99
# Object found in Screenshot_80.png with confidence: 0.87
# Object not found in Screenshot_81.png. Confidence: 0.45
# Object found in Screenshot_82.png with confidence: 0.68
# Object found in Screenshot_83.png with confidence: 0.72
# Object not found in Screenshot_84.png. Confidence: 0.53
# Object found in Screenshot_85.png with confidence: 0.66
# Object not found in Screenshot_86.png. Confidence: 0.48
# Object found in Screenshot_87.png with confidence: 0.77
# Object found in Screenshot_88.png with confidence: 0.79
# Object not found in Screenshot_89.png. Confidence: 0.35
# Object found in Screenshot_9.png with confidence: 0.99
# Object not found in Screenshot_90.png. Confidence: 0.53
# Object found in Screenshot_91.png with confidence: 0.63
# Object not found in Screenshot_92.png. Confidence: 0.24
# Object found in Screenshot_93.png with confidence: 0.60
# Object found in Screenshot_94.png with confidence: 0.62
# Object found in Screenshot_95.png with confidence: 0.81
# Object found in Screenshot_96.png with confidence: 0.74
# Object found in Screenshot_97.png with confidence: 0.78
# Object found in Screenshot_98.png with confidence: 0.80
# Object found in Screenshot_99.png with confidence: 0.81
# Detection and saving complete.
